# %% [markdown]
# ### **Tools & Binding**

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
model = ChatGoogleGenerativeAI(
    model = "gemini-3.6-flash"
)


print(f"[INFO] Model : {model.model} Loaded Successfully!")
# Out:
# [INFO] Model : gemini-3.6-flash Loaded Successfully!

# %% [markdown]
# ### **DuckDuckGo Search tool**

# %%
from langchain_community.tools import DuckDuckGoSearchRun

duck_search = DuckDuckGoSearchRun()

duck_search.invoke("Latest Scorecard update on Ind vs Sl test series")
# Out:
# '1 day ago · Follow IND 460/9 (116) (Prasidh Krishna 1(4) Kuldeep Yadav 12(13)) | Sri Lanka vs India, 1st Test, India tour of Sri Lanka 2026 live with live scores, ball-by-ball commentary, highlights, videos ... Track latest match scores, schedule, and results of India in Sri Lanka Test Series. Get full coverage of India tour of Sri Lanka with live cricket scores, latest match results, and the updated points table. Sri Lanka vs India live cricket scorecard (SL vs IND): Get Sri Lanka vs India live score with ball-by-ball updates full scorecard, key stats and match highlights from 1st Test of the IND in SL 2 Tests 2026 at Galle International Stadium, Galle on IndiaToday.in. Catch the fastest live cricket scores and ball-by-ball commentary. Get real-time updates, full scorecards, and match analysis for the IPL 2026 & all global and domestic series.'

# %% [markdown]
# ### **Arxiv tool - research paper**

# %%
from langchain_community.tools import ArxivQueryRun
from langchain_community.utilities import ArxivAPIWrapper

arxiv_query = ArxivQueryRun(api_wrapper=ArxivAPIWrapper(), max_results = 2)
arxiv_query.invoke("Transformer models in NLP")
