# %% [markdown]
# ### **Prompts In LangGraph**

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
model = ChatGoogleGenerativeAI(
    model = "gemini-3.6-flash"
)


print(f"[INFO] Model : {model.model} Loaded Successfully!")
# Out:
# [INFO] Model : gemini-3.6-flash Loaded Successfully!

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are helpful assistant that helps to create and curate posts for a social media platform."),
        ("user", "I want to create a post about the topic using AOP concepts")
    ]
)

prompt
# Out:
# ChatPromptTemplate(input_variables=[], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are helpful assistant that helps to create and curate posts for a social media platform.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='I want to create a post about the topic using AOP concepts'), additional_kwargs={})])
