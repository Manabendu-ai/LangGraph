# %% [markdown]
# ### **Prompts In LangGraph**

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
model = ChatGoogleGenerativeAI(
    model = "gemini-3.6-flash"
)


print(f"[INFO] Model : {model.model} Loaded Successfully!")
# Out:
# [INFO] Model : gemini-3.6-flash Loaded Successfully!

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are helpful assistant that helps to create and curate posts for a social media platform."),
        ("user", "I want to create a post about the topic {topic}")
    ]
)

# %%
filled_prompt = prompt.invoke(
    {
        "topic" : "Importance of AOP"
    }
)
filled_prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are helpful assistant that helps to create and curate posts for a social media platform.', additional_kwargs={}, response_metadata={}), HumanMessage(content='I want to create a post about the topic Importance of AOP', additional_kwargs={}, response_metadata={})])

# %%
model.invoke(filled_prompt).content[0]['text']
# Out:
# 'Here are a few options for a social media post about the **Importance of Aspect-Oriented Programming (AOP)**, tailored for different platforms and styles:\n\n---\n\n### Option 1: Professional & Educational (Best for LinkedIn)\n\n**Title:** Ever feel like your clean code is being "polluted" by non-business logic? 🛑\n\nWhen writing software, we’ve all been there: you write a 10-line business logic method, but end up adding 30 lines of logging, security checks, and transaction management around it. \n\nThis is where **Aspect-Oriented Programming (AOP)** comes to the rescue! 🚀\n\nAOP is a programming paradigm designed to solve the problem of **Cross-Cutting Concerns**—features that span across multiple parts of an application.\n\n💡 **Why is AOP so important?**\n\n1️⃣ **Separation of Concerns:** Keep your core business logic pure and focused on *what* it needs to do, without distraction.\n2️⃣ **Reduces Boilerplate Code (DRY Principle):** Instead of duplicating logging or auth checks ever
# ...

# %% [markdown]
# ### **Chain With Prompts**

# %%
chain = prompt | model

# %%
chain.invoke(
    {
        "topic" : "importance of API health endpoint."
    }
).content[0]['text']
# Out:
# 'Here are a few options tailored for different social media platforms and tones. \n\n---\n\n### Option 1: LinkedIn (Professional & Educational) — *Best for thought leadership*\n\n**Caption:**\nIf your API doesn’t have a `/health` endpoint, are you really monitoring your application? 🩺👇\n\nA Health Endpoint is one of the simplest yet most crucial features of a production-ready API. It gives you a real-time status check on whether your service is operational.\n\nHere is why every backend developer and DevOps engineer should prioritize it:\n\n1️⃣ **Automated Recovery (Kubernetes & Load Balancers):**\nOrchestrators use health endpoints to know when to route traffic to a container (Readiness Probe) or when to restart a crashed instance (Liveness Probe).\n\n2️⃣ **Dependency Verification:**\nA true health check doesn\'t just say "I\'m alive." It checks downstream dependencies—can your service still connect to the database, Redis cache, or third-party APIs?\n\n3️⃣ **Faster Incident Response 
# ...
