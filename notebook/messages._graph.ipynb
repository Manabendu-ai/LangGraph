# %% [markdown]
# ### **Messages Graph**

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
model = ChatGoogleGenerativeAI(
    model = "gemini-3.6-flash"
)


print(f"[INFO] Model : {model.model} Loaded Successfully!")
# Out:
# [INFO] Model : gemini-3.6-flash Loaded Successfully!

# %% [markdown]
# ### **Human Message**

# %%
from langchain_core.messages import HumanMessage

model.invoke(
    [
        HumanMessage(
            content="Tell me about the WORLD WAR II. (under 100 words)."
        )
    ]
).content[0]['text']
# Out:
# 'World War II (1939–1945) was the deadliest conflict in human history. Fought globally between the Allies (led by the US, UK, and Soviet Union) and the Axis powers (led by Nazi Germany, Japan, and Italy), it began when Germany invaded Poland. \n\nThe war featured major events like the Holocaust, Pearl Harbor, D-Day, and the first use of nuclear weapons. It ended in 1945 after Germany surrendered and the US dropped atomic bombs on Hiroshima and Nagasaki. Claiming an estimated 70–85 million lives, WWII reshaped global borders and led to the creation of the United Nations.'
